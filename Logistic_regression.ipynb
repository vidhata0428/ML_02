# %% [markdown]
# <a href="https://colab.research.google.com/github/vidhata0428/ML_02/blob/main/Logistic_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
sales=pd.read_csv("Product_sales.csv")
sales
# Out:
#      Age  Bought
# 0      1       0
# 1      1       0
# 2      1       0
# 3      1       0
# 4      1       0
# ..   ...     ...
# 462   43       0
# 463   60       1
# 464   63       1
# 465   50       0
# 466   61       1
#
# [467 rows x 2 columns]

# %%
#Classification problem by Linear Regression - Wrong Model
import sklearn as sk
from sklearn import linear_model

from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(sales[["Age"]],sales[["Bought"]])
d1=pd.DataFrame({"Age":[4]})
predict1=lr.predict(d1)
print(predict1)

d2=pd.DataFrame({"Age":[105]})
predict2=lr.predict(d2)
print(predict2)
# Out:
# [[-0.08664394]]
# [[2.02851132]]

# %%
#Logistics Regression
import sklearn as sk
from sklearn import linear_model
from sklearn.linear_model import LogisticRegression

lr=LogisticRegression()
lr.fit(sales[["Age"]],sales[["Bought"]])
d1=pd.DataFrame({"Age":[4]})
predict1=lr.predict(d1)
print(predict1)

d2=pd.DataFrame({"Age":[105]})
predict2=lr.predict(d2)
print(predict2)
# Out:
# [0]
# [1]
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
sales["Age"].value_counts().head(2)
# Out:
# Age
# 12    23
# 1     17
# Name: count, dtype: int64

# %%
sales["Age"].value_counts().sort_index().head(2)
# Out:
# Age
# 1    17
# 2    11
# Name: count, dtype: int64

# %%
import sklearn as sk
from sklearn import linear_model
from sklearn.linear_model import LogisticRegression

lr=LogisticRegression()
lr.fit(sales[["Age"]],sales[["Bought"]])

d1=pd.DataFrame({"Age":[12]})
predict1=lr.predict(d1)
print(predict1)
d2=pd.DataFrame({"Age":[72]})
predict2=lr.predict(d2)
print(predict2)
# Out:
# [0]
# [1]
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
print("Intercept",lr.intercept_)
print("Coefficient",lr.coef_) #Although Logistic regression doesnt directly computes corelaion coefficient
# Out:
# Intercept [-6.90722429]
# Coefficient [[0.21777169]]

# %%
Fiber = pd.read_csv("Fiberbits_v1.csv")
Fiber.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   active_cust                 100000 non-null  int64
#  1   income                      100000 non-null  int64
#  2   months_on_network           100000 non-null  int64
#  3   Num_complaints              100000 non-null  int64
#  4   number_plan_changes         100000 non-null  int64
#  5   relocated                   100000 non-null  int64
#  6   monthly_bill                100000 non-null  int64
#  7   technical_issues_per_month  100000 non-null  int64
#  8   Speed_test_result           100000 non-null  int64
# dtypes: int64(9)
# memory usage: 6.9 MB

# %%
import sklearn as sk
from sklearn.linear_model import LogisticRegression

logistic1 = LogisticRegression()
logistic1.fit(Fiber[["income"]+["months_on_network"]+["Num_complaints"]+["number_plan_changes"]+["relocated"]+["monthly_bill"]+["technical_issues_per_month"]+["Speed_test_result"]],Fiber[["active_cust"]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
#Individual customer prediction
import pandas as pd

new_customer = pd.DataFrame({
    "income": [50000],
    "months_on_network": [12],
    "Num_complaints": [1],
    "number_plan_changes": [0],
    "relocated": [0],
    "monthly_bill": [1200],
    "technical_issues_per_month": [1],
    "Speed_test_result": [95]
})

prediction = logistic1.predict(new_customer)
print("Will customer stay?" , "Yes" if prediction[0] == 1 else "No")

#1 true i.e. customer will stay , 0 cust will not stay
# Out:
# Will customer stay? No

# %%
#All customer prediction
predictions = logistic1.predict(Fiber[["income", "months_on_network", "Num_complaints",
                                       "number_plan_changes", "relocated",
                                       "monthly_bill", "technical_issues_per_month",
                                       "Speed_test_result"]])
predictions[:10]
# Out:
# array([1, 1, 0, 0, 1, 1, 1, 1, 1, 1])

# %%
from sklearn.metrics import confusion_matrix
predict1=logistic1.predict(Fiber[["income"]+["months_on_network"]+["Num_complaints"]+
                            ["number_plan_changes"]+["relocated"]+["monthly_bill"]+
                            ["technical_issues_per_month"]+["Speed_test_result"]])
predict1
cm1=confusion_matrix(Fiber[["active_cust"]],predict1)
print(cm1) #Gives the confusion array

total1=sum(sum(cm1))
print(total1)

accuracy1=(cm1[0,0]+cm1[1,1])/total1 #True postive[0,0] + False Negative[1,1] / Total
print(accuracy1)
# Out:
# [[33872  8269]
#  [ 6168 51691]]
# 100000
# 0.85563

# %%
#Model Validation
#Checking interdepencies using VIF
import statsmodels.formula.api as sm

def vif_cal(input_data, dependent_col):
    x_vars=input_data.drop([dependent_col], axis=1)
    xvar_names=x_vars.columns
    for i in range(0,xvar_names.shape[0]):
        y=x_vars[xvar_names[i]]
        x=x_vars[xvar_names.drop(xvar_names[i])]
        rsq=sm.ols(formula="y~x", data=x_vars).fit().rsquared
        vif=round(1/(1-rsq),2)
        print (xvar_names[i], " VIF = " , vif)

# %%
vif_cal(input_data=Fiber, dependent_col="active_cust")
# Out:
# income  VIF =  1.02
# months_on_network  VIF =  1.04
# Num_complaints  VIF =  1.17
# number_plan_changes  VIF =  11.98
# relocated  VIF =  1.61
# monthly_bill  VIF =  1.0
# technical_issues_per_month  VIF =  11.44
# Speed_test_result  VIF =  1.14
